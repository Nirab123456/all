# %%
import pandas as pd

# %%
drug_df = pd.read_csv('C:/langchain2/data_medical/drugand_med\Drug_clean.csv')

# %%
drug_df
# Out:
#                      Condition                         Drug  EaseOfUse
# 0    Acute Bacterial Sinusitis                  Amoxicillin   3.852353  \
# 1    Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   3.470000
# 2    Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   3.121429
# 3    Acute Bacterial Sinusitis                   Ampicillin   2.000000
# 4    Acute Bacterial Sinusitis                   Ampicillin   3.250000
# ..                         ...                          ...        ...
# 680   vulvovaginal candidiasis           Miconazole Nitrate   3.465000
# 681   vulvovaginal candidiasis      Miconazole-Skin Clnsr17   4.750000
# 682   vulvovaginal candidiasis      Miconazole-Skin Clnsr17   4.000000
# 683   vulvovaginal candidiasis                  Terconazole   3.525000
# 684   vulvovaginal candidiasis                  Tioconazole   3.852500
#
#      Effective            Form Indication       Price     Reviews
# ...

# %%
collum_names= ['EaseOfUse','Effective','Form','Indication','Price','Reviews','Satisfaction','Type']

# %%
drug_df = drug_df.drop(collum_names, axis=1)

# %%
drug_df
# Out:
#                      Condition                         Drug
# 0    Acute Bacterial Sinusitis                  Amoxicillin
# 1    Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate
# 2    Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate
# 3    Acute Bacterial Sinusitis                   Ampicillin
# 4    Acute Bacterial Sinusitis                   Ampicillin
# ..                         ...                          ...
# 680   vulvovaginal candidiasis           Miconazole Nitrate
# 681   vulvovaginal candidiasis      Miconazole-Skin Clnsr17
# 682   vulvovaginal candidiasis      Miconazole-Skin Clnsr17
# 683   vulvovaginal candidiasis                  Terconazole
# 684   vulvovaginal candidiasis                  Tioconazole
#
# [685 rows x 2 columns]

# %%
# Assuming you have a DataFrame called 'drug_df' and a specific column name 'column_name'
specific_string = "which medication is used for "
drug_df['Condition'] = specific_string + drug_df['Condition'].astype(str)
# lower case
drug_df = drug_df.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
drug_df
# Out:
#                                              Condition
# 0    which medication is used for acute bacterial s...  \
# 1    which medication is used for acute bacterial s...
# 2    which medication is used for acute bacterial s...
# 3    which medication is used for acute bacterial s...
# 4    which medication is used for acute bacterial s...
# ..                                                 ...
# 680  which medication is used for vulvovaginal cand...
# 681  which medication is used for vulvovaginal cand...
# 682  which medication is used for vulvovaginal cand...
# 683  which medication is used for vulvovaginal cand...
# 684  which medication is used for vulvovaginal cand...
#
#                             Drug
# 0                    amoxicillin
# 1    amoxicillin-pot clavulanate
# 2    amoxicillin-pot clavulanate
# 3                     ampicillin
# 4                     ampicillin
# ..                           ...
# 680           miconazole nitrate
# ...

# %%
drug_df = drug_df.astype(str)

# %%
drug_df
# Out:
#                                              Condition
# 0    which medication is used for acute bacterial s...  \
# 1    which medication is used for acute bacterial s...
# 2    which medication is used for acute bacterial s...
# 3    which medication is used for acute bacterial s...
# 4    which medication is used for acute bacterial s...
# ..                                                 ...
# 680  which medication is used for vulvovaginal cand...
# 681  which medication is used for vulvovaginal cand...
# 682  which medication is used for vulvovaginal cand...
# 683  which medication is used for vulvovaginal cand...
# 684  which medication is used for vulvovaginal cand...
#
#                             Drug
# 0                    amoxicillin
# 1    amoxicillin-pot clavulanate
# 2    amoxicillin-pot clavulanate
# 3                     ampicillin
# 4                     ampicillin
# ..                           ...
# 680           miconazole nitrate
# ...

# %%
new_column_order = ['Drug', 'Condition']

# %%
# Reorder the columns in the DataFrame
drug_df = drug_df[new_column_order]

# %%
drug_df
# Out:
#                             Drug
# 0                    amoxicillin  \
# 1    amoxicillin-pot clavulanate
# 2    amoxicillin-pot clavulanate
# 3                     ampicillin
# 4                     ampicillin
# ..                           ...
# 680           miconazole nitrate
# 681      miconazole-skin clnsr17
# 682      miconazole-skin clnsr17
# 683                  terconazole
# 684                  tioconazole
#
#                                              Condition
# 0    which medication is used for acute bacterial s...
# 1    which medication is used for acute bacterial s...
# 2    which medication is used for acute bacterial s...
# 3    which medication is used for acute bacterial s...
# 4    which medication is used for acute bacterial s...
# ..                                                 ...
# 680  which medication is used for vulvovaginal cand...
# 681  which medication is used for vulvovaginal cand...
# 682  which medication is used for vulvovaginal cand...
# ...

# %%
drug_df.to_csv('C:/langchain2/data_medical/generic_drug_processd_1.csv', index=False)
